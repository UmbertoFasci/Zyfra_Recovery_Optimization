# %%
from great_tables import GT
import pandas as pd

# Create the data
data = pd.DataFrame([
    ["Linear Regression", "Rougher", "MAE", 6.8421, 6.9611],
    ["Linear Regression", "Rougher", "sMAPE", 10.5918, 10.6660],
    ["Basic Random Forest", "Rougher", "MAE", 1.7134, 4.2492],
    ["Basic Random Forest", "Rougher", "sMAPE", 5.4860, 8.1685],
    ["Tuned Random Forest", "Rougher", "MAE", 2.0006, 4.1228],
    ["Tuned Random Forest", "Rougher", "sMAPE", 5.8330, 7.9791],
    ["Linear Regression", "Final", "MAE", 6.4453, 6.6985],
    ["Linear Regression", "Final", "sMAPE", 10.7009, 10.9889],
    ["Basic Random Forest", "Final", "MAE", 1.7309, 4.7238],
    ["Basic Random Forest", "Final", "sMAPE", 3.9751, 8.1635],
    ["Tuned Random Forest", "Final", "MAE", 1.9241, 4.6137],
    ["Tuned Random Forest", "Final", "sMAPE", 4.1946, 7.9889]
],
    columns=["Model Type", "Recovery Type", "Metric", "Training", "Test"]
)

# Create and format the table
gt = (GT(data)
    .fmt_number(["Training", "Test"], decimals=4)
    .tab_header(
        title=("Modeling Metrics"),
    )
    .tab_spanner(
        label=("Performance"),
        columns=["Training", "Test"]
    )
    .data_color(
        columns="Training",
        palette=["#c6efce", "#ffeb9c", "#ffc7ce"]
    )
    .data_color(
        columns="Test",
        palette=["#c6efce", "#ffeb9c", "#ffc7ce"]
    ))

# %%
# Create the data
data = pd.DataFrame([
    ["Linear Regression", "Rougher", [0.00, 100.00], [51.24, 125.88], 10.67],
    ["Linear Regression", "Final", [0.00, 100.00], [35.38, 107.49], 10.91],
    ["Basic Random Forest", "Rougher", [0.00, 100.00], [1.71, 96.92], 8.17],
    ["Basic Random Forest", "Final", [0.00, 100.00], [19.68, 100.00], 8.16],
    ["Tuned Random Forest", "Rougher", [0.00, 100.00], [2.90, 96.05], 7.9],
    ["Tuned Random Forest", "Final", [0.00, 100.00], [21.32, 100.00], 7.99]
],
    columns=["Model Type", "Recovery Type", "True Value Range", "Predicted Value Range", "sMAPE"]
)

# Create and format the table
gt2 = (GT(data)
    .fmt_number("sMAPE", decimals=2)
    .tab_header(
        title=("Final sMAPE"),
    )
    .tab_spanner(
        label=("Value Range"),
        columns=["True Value Range", "Predicted Value Range"]
    )
    .data_color(
        columns="sMAPE",
        palette=["#c6efce", "#ffeb9c", "#ffc7ce"]
    ))
# Out:
# GT(_tbl_data=            Model Type Recovery Type True Value Range Predicted Value Range  \
# 0    Linear Regression       Rougher     [0.0, 100.0]       [51.24, 125.88]
# 1    Linear Regression         Final     [0.0, 100.0]       [35.38, 107.49]
# 2  Basic Random Forest       Rougher     [0.0, 100.0]         [1.71, 96.92]
# 3  Basic Random Forest         Final     [0.0, 100.0]        [19.68, 100.0]
# 4  Tuned Random Forest       Rougher     [0.0, 100.0]          [2.9, 96.05]
# 5  Tuned Random Forest         Final     [0.0, 100.0]        [21.32, 100.0]
#
#    sMAPE
# 0  10.67
# 1  10.91
# 2   8.17
# 3   8.16
# 4   7.90
# 5   7.99  , _body=<great_tables._gt_data.Body object at 0x7f3b24331ee0>, _boxhead=Boxhead([ColInfo(var='Model Type', type=<ColInfoTypeEnum.default: 1>, column_label='Model Type', column_align='left', column_width=None), ColInfo(var='Recovery Type', type=<ColInfoTypeEnum.default: 1>, column_label='Recovery Type', column_align='left', column_width=None), ColInfo(var='True Value Range', type=<ColInfoTypeEnum.default: 1>, column_label='True Value Range', column_align='right', column_width=None), ColInfo(var='Predicted Value Range', type=<ColInfoTypeEnum.default: 1>, column_label='Predicted Value Range', column_align='right', column_width=None), ColInfo(var='sMAPE', type=<ColInfoTypeEnum.default: 1>, column_label='sMAPE', column_align='right', column_width=None)]), _stub=<great_tables._gt_data.Stub object at 0x7f3b24332210>, _spanners=Spanners([SpannerInfo(spanner_id='Value Range', spanner_level=0, spanner_label='Value Range', spanner_units=None, spanner_pattern=None, vars=['True Value Range', 'Predicted Value Range'], built=None)]), _heading=Heading(title='Final sMAPE', subtitle=None, preheader=None), _stubhead=None, _source_notes=[], _footnotes=[], _styles=[StyleInfo(locname=LocBody(columns='sMAPE', rows=[0]), grpname=None, colname='sMAPE', rownum=0, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ffcdc6')]), StyleInfo(locname=LocBody(columns='sMAPE', rows=[1]), grpname=None, colname='sMAPE', rownum=1, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#ffc7ce')]), StyleInfo(locname=LocBody(columns='sMAPE', rows=[2]), grpname=None, colname='sMAPE', rownum=2, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#d0eec5')]), StyleInfo(locname=LocBody(columns='sMAPE', rows=[3]), grpname=None, colname='sMAPE', rownum=3, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#d0eec5')]), StyleInfo(locname=LocBody(columns='sMAPE', rows=[4]), grpname=None, colname='sMAPE', rownum=4, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#c6efce')]), StyleInfo(locname=LocBody(columns='sMAPE', rows=[5]), grpname=None, colname='sMAPE', rownum=5, colnum=None, styles=[CellStyleText(color='#000000', font=None, size=None, align=None, v_align=None, style=None, weight=None, stretch=None, decorate=None, transform=None, whitespace=None), CellStyleFill(color='#c9efcb')])], _locale=<great_tables._gt_data.Locale object at 0x7f3b091a6fc0>, _formats=[<great_tables._gt_data.FormatInfo object at 0x7f3b091a72c0>], _substitutions=[], _options=Options(table_id=OptionsInfo(scss=False, category='table', type='value', value=None), table_caption=OptionsInfo(scss=False, category='table', type='value', value=None), table_width=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_layout=OptionsInfo(scss=True, category='table', type='value', value='fixed'), table_margin_left=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_margin_right=OptionsInfo(scss=True, category='table', type='px', value='auto'), table_background_color=OptionsInfo(scss=True, category='table', type='value', value='#FFFFFF'), table_additional_css=OptionsInfo(scss=False, category='table', type='values', value=[]), table_font_names=OptionsInfo(scss=False, category='table', type='values ...
